# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\Sites\Pagina Hashtag.html"
navegador.get(arquivo)

# %% [markdown]
# #### Pegar informações de um elemento
#
# - texto
# - atributos

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ##### Ex1: Link do Whatsapp

# %%
lista_elementos = navegador.find_elements(By.CLASS_NAME, 'nav-link')

for elemento in lista_elementos:
    if 'contato' in elemento.text.lower():
        elemento.click()
        break

texto = navegador.find_element(By.XPATH, '/html/body/footer/div/div/div[1]/div[2]/div[5]/div/a').get_attribute('href')
print(texto)
# Out:
# https://api.whatsapp.com/send?phone=5521996582442&text=Ol%C3%A1%2C%20gostaria%20de%20tirar%20uma%20d%C3%BAvida%20%20sobre%20o%20curso%20online

# %% [markdown]
# ##### Ex2: Imagens dos cursos

# %%
link_imagem = navegador.find_element(By.CLASS_NAME, 'wp-image-13719').get_attribute('src')
link = navegador.find_element(By.XPATH, '/html/body/section[2]/div/div[8]/figure/a').get_attribute('href')
print(link_imagem)
print('-' * 234)
print(link)
# Out:
# file:///C:/Users/Neylor/Downloads/Python/Selenium/Pagina%20Hashtag_files/Box-Python-Impressionador-1024x576.png.webp
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# https://www.hashtagtreinamentos.com/curso-python
