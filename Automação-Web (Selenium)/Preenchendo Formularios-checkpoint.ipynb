# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\Sites\formulario.html"
navegador.get(arquivo)

# %% [markdown]
# #### Botão Padrão (clicar em botão)

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[1]').click()
alerta = navegador.switch_to.alert
alerta.dismiss()

# %% [markdown]
# #### Dica, esteja atento ao atributo "value" dos inputs, ele pode te ajudar
#
# - .text
# - .get_attribute("value")
# - .is_selected

# %% [markdown]
# #### Botão de Seleção estilo Checkbox (clicar no botão)

# %%
# clicar no botão
navegador.find_element(By.XPATH, '/html/body/form/input[3]').click()

# %%
# verificar o valor do botão
valor = navegador.find_element(By.XPATH, '/html/body/form/input[3]').is_selected()
print(valor)
# Out:
# True

# %%
if valor == True:
   navegador.find_element(By.XPATH, '/html/body/form/input[3]').click()

# %% [markdown]
# #### Botão de Seleção de Cores (enviar valor)

# %%
# preencher a cor
vermelho1 = navegador.find_element(By.XPATH, '/html/body/form/input[4]').send_keys('#ffffff')
vermelho2 = navegador.find_element(By.XPATH, '/html/body/form/input[5]').send_keys('#742093')

# %%
# verificar qual a cor foi selecionada
valor = navegador.find_element(By.XPATH, '/html/body/form/input[4]').get_attribute('value')
print(valor)
valor2 = navegador.find_element(By.XPATH, '/html/body/form/input[5]').get_attribute('value')
print(valor2)
# Out:
# #ffffff
# #742093

# %% [markdown]
# #### Botão de Datas (enviar valor)

# %%
# preencher o valor
navegador.find_element(By.XPATH, '/html/body/form/input[6]').send_keys('24/08/2005')

# %%
# pegar o valor
valor = navegador.find_element(By.XPATH, '/html/body/form/input[6]').get_attribute('value')
print(valor)
# Out:
# 2005-08-24

# %% [markdown]
# #### Botão de Datas com Horas (enviar valor)

# %%
# preenchendo
from selenium.webdriver.common.keys import Keys
navegador.find_element(By.XPATH, '/html/body/form/input[7]').send_keys('24/08/2005', Keys.TAB, '11:37')

# %%
# pegando o valor
valor = navegador.find_element(By.XPATH, '/html/body/form/input[7]').get_attribute('value')
print(valor)
# Out:
# 2005-08-24T11:37

# %% [markdown]
# #### Botão para selecionar o arquivo (enviar valor com caminho completo)

# %%
# preenchendo
navegador.find_element(By.XPATH, '/html/body/form/input[8]').send_keys(r'C:\Users\Neylor\Downloads\Python\For')

# %%
caminho = os.getcwd()
arquivo = caminho + r"\Sites\formulario.html"
navegador.get(arquivo)

navegador.find_element(By.XPATH, '/html/body/form/input[8]').send_keys(arquivo)

# %%
# pegar o valor
valor = navegador.find_element(By.XPATH, '/html/body/form/input[8]').get_attribute('value')
print(valor)
# Out:
# C:\fakepath\formulario.html

# %% [markdown]
# #### Botão para selecionar mês e ano (enviar valor)

# %%
# preenche
navegador.find_element(By.XPATH, '/html/body/form/input[9]').send_keys('ago', Keys.TAB, '2005')
# valor
valor = navegador.find_element(By.XPATH, '/html/body/form/input[9]').get_attribute('value')
print(valor)
# Out:
# 2005-08

# %% [markdown]
# #### método clear serve para limpar o campo

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[10]').clear()

# %% [markdown]
# #### Campos Numéricos

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[10]').send_keys('123457')

# %%
valor = navegador.find_element(By.XPATH, '/html/body/form/input[10]').get_attribute('value')
print(valor)
# Out:
# 123457

# %% [markdown]
# #### Campos de Senha

# %%
# preencher
navegador.find_element(By.XPATH, '/html/body/form/input[11]').send_keys('N3ylor2005')
# pego o valor
senha = navegador.find_element(By.XPATH, '/html/body/form/input[11]').get_attribute('value')
print(senha)
# Out:
# N3ylor2005

# %% [markdown]
# #### RadioButtons (botões que só consegue marcar 1)

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[13]').click()

# %%
valor = navegador.find_element(By.XPATH, '/html/body/form/input[13]').is_selected()
print(valor)
# Out:
# True

# %% [markdown]
# #### Slider (enviar valor)

# %%
# pegar o valor
valor = navegador.find_element(By.XPATH, '/html/body/form/input[15]').get_attribute('value')
print(valor)
# Out:
# 50

# %%
# preencher o valor
elemento = navegador.find_element(By.XPATH, '/html/body/form/input[15]')
elemento.clear()

# pra frente
for i in range (70 - 50):
    elemento.send_keys(Keys.ARROW_RIGHT)
valor = navegador.find_element(By.XPATH, '/html/body/form/input[15]').get_attribute('value')
print(valor)


elemento.clear() 
# pra trás
for i in range (50 - 20):
    elemento.send_keys(Keys.ARROW_LEFT)    
valor = navegador.find_element(By.XPATH, '/html/body/form/input[15]').get_attribute('value')
print(valor)
# Out:
# 70
# 20

# %% [markdown]
# #### Caixa de Texto

# %%
# preencher
navegador.find_element(By.XPATH, '/html/body/form/input[16]').send_keys('Atlético')

# %%
valor = navegador.find_element(By.XPATH, '/html/body/form/input[16]').get_attribute('value')
print(valor)
# Out:
# Atlético

# %% [markdown]
# #### Caixa de Horas

# %%
from datetime import datetime

horas = datetime.now()
horas.strftime('%d/%m/%Y %H:%M')
horas = str(horas)
horas = horas[11:16]
print(datetime.now())

navegador.find_element(By.XPATH, '/html/body/form/input[17]').send_keys(horas)
valor = navegador.find_element(By.XPATH, '/html/body/form/input[17]').get_attribute('value')
print(valor)
# Out:
# 2023-05-29 20:42:58.186479
# 20:42

# %% [markdown]
# #### Caixa de Data Personalizada (Semanal)

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[18]').send_keys('10','2007')

# %% [markdown]
# #### Blocos de texto (enviar valor)

# %%
navegador.find_element(By.XPATH, '//*[@id="story"]').send_keys('iai fi', Keys.ENTER, 'suave', Keys.ENTER, '?')
navegador.find_element(By.XPATH, '//*[@id="story"]').clear()

# %% [markdown]
# #### Selecionando itens de uma lista

# %%
# preencher o valor
navegador.find_element(By.XPATH, '/html/body/form/select[1]').send_keys('a')

# %%
# pegando o valor
valor = navegador.find_element(By.XPATH, '/html/body/form/select[1]').get_attribute('value')
print(valor)
# Out:
# a

# %%
# clicando para selecionar
import time
time.sleep(0.5)
navegador.find_element(By.XPATH, '/html/body/form/select[1]').click()
#A
navegador.find_element(By.XPATH, '/html/body/form/select[1]/option[3]').click()
#B
# navegador.find_element(By.XPATH, '/html/body/form/select[1]/option[2]').click
#C
# navegador.find_element(By.XPATH, '/html/body/form/select[1]/option[3]').click

# %%
# do meu jeito
navegador.find_element(By.XPATH, '/html/body/form/select[1]').clear
navegador.find_element(By.XPATH, '/html/body/form/select[1]').click()
navegador.find_element(By.XPATH, '/html/body/form/select[1]').send_keys()
# deu errado 😪

# %%
# com o select
from selenium.webdriver.support.select import Select

elemento = navegador.find_element(By.TAG_NAME, 'select')
elemento_select = Select(elemento)
# próxima aula
# https://www.selenium.dev/pt-br/documentation/webdriver/elements/select_lists/

# %%
elemento_select.select_by_index(0)
elemento_select.select_by_value('c')
elemento_select.select_by_visible_text('B')

# %%
# ler o item selecionado
item = elemento_select.first_selected_option
print(item.get_attribute('value'))

#se fosse mais de uma opção, tipo o 'find_elements e o find_element
lista_itens = elemento_select.all_selected_options
print(lista_itens)
print(lista_itens[0].get_attribute('value'))
print(lista_itens[0].text)
# find_element = elemento
# find_elements = [elemento1, elemento2, elemento3]
