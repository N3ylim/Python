# %% [markdown]
# # Python e API
#
# ### O que é uma API?
#
# - É um conjunto de códigos para usar um serviço/site/aplicativo específico. Cada site/ferramenta tem sua própria API. É importante que você saiba ler as APIs que precisar para saber usar
#
# - Um dos padrões mais comuns em API é pegar informações em formato json, uma espécie de dicionário que precisa ser tratada no Python para podermos analisar
#
# - As possibilidades de API são infinitas, vamos fazer 2 exemplos aqui: Cotação de Moedas e Envio de SMS.
#
# - Sites como Google, Youtube, Facebook, Twitter, ArcGis e praticamente qualquer ferramenta/site grande tem uma API.
#
# ### O que precisamos:
#
# - Quase sempre você precisa de uma conta para consumir uma API. Algumas APIs são abertas, como a https://docs.awesomeapi.com.br/api-de-moedas , mas em muitos casos (como veremos no caso do SMS) vamos precisar ter uma conta ativa para consumir a API
#
# - A Documentação da API (ou exemplos da internet) é a chave para conseguir usar uma API

# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
import requests
import json

cota = requests.get("https://economia.awesomeapi.com.br/json/all")
cota_dic = cota.json()
print(cota_dic)
# Out:
# {'USD': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '4.7288', 'low': '4.7271', 'varBid': '0.0001', 'pctChange': '0', 'bid': '4.7269', 'ask': '4.7274', 'timestamp': '1690232405', 'create_date': '2023-07-24 18:00:05'}, 'USDT': {'code': 'USD', 'codein': 'BRLT', 'name': 'Dólar Americano/Real Brasileiro Turismo', 'high': '4.76', 'low': '4.76', 'varBid': '0', 'pctChange': '0', 'bid': '4.62', 'ask': '4.9', 'timestamp': '1690225560', 'create_date': '2023-07-24 16:06:00'}, 'CAD': {'code': 'CAD', 'codein': 'BRL', 'name': 'Dólar Canadense/Real Brasileiro', 'high': '3.5916', 'low': '3.5881', 'varBid': '-0.0017', 'pctChange': '-0.05', 'bid': '3.5867', 'ask': '3.5922', 'timestamp': '1690246703', 'create_date': '2023-07-24 21:58:23'}, 'GBP': {'code': 'GBP', 'codein': 'BRL', 'name': 'Libra Esterlina/Real Brasileiro', 'high': '6.0648', 'low': '6.0533', 'varBid': '-0.0023', 'pctChange': '-0.04', 'bid': '6.0533', 'ask': '6.068', 'timestamp': '1690246695', 'create_date': '2023-07-24 21:58:15'}, 'ARS': {'code': 'ARS', 'codein': 'BRL', 'name': 'Peso Argentino/Real Brasileiro', 'high': '0.0174', 'low': '0.0174', 'varBid': '0', 'pctChange': '0', 'bid': '0.0174', 'ask': '0.0174', 'timestamp': '1690246687', 'create_date': '2023-07-24 21:58:07'}, 'BTC': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '144967', 'low': '138000', 'varBid': '-5872', 'pctChange': '-4.05', 'bid': '139041', 'ask': '139041', 'timestamp': '1690246548', 'create_date': '2023-07-24 21:55:48'}, 'LTC': {'code': 'LTC', 'codein': 'BRL', 'name': 'Litecoin/Real Brasileiro', 'high': '449.03', 'low': '419.01', 'varBid': '-22.84', 'pctChange': '-5.09', 'bid': '424.23', 'ask': '425.5', 'timestamp': '1690246595', 'create_date': '2023-07-24 21:56:35'}, 'EUR': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '5.2325', 'low': '5.2292', 'varBid': '0.0005', 'pctChange': '0.01', 'bid': '5.2285', 'ask': '5.2365', 'timestamp': '1690246700', 'create_date': '2023-07-24 21:58:20'}, 'JPY': {'code': 'JPY', 'codein': 'BRL', 'name': 'Iene Japonês/Real Brasileiro', 'high': '0.03343', 'low': '0.03339', 'varBid': '0', 'pctChange': '0', 'bid': '0.03342', 'ask': '0.03344', 'timestamp': '1690246690', 'create_date': '2023-07-24 21:58:10'}, 'CHF': {'code': 'CHF', 'codein': 'BRL', 'name': 'Franco Suíço/Real Brasileiro', 'high': '5.4384', 'low': '5.4337', 'varBid': '0.0011', 'pctChange': '0.02', 'bid': '5.4342', 'ask': '5.4425', 'timestamp': '1690246695', 'create_date': '2023-07-24 21:58:15'}, 'AUD': {'code': 'AUD', 'codein': 'BRL', 'name': 'Dólar Australiano/Real Brasileiro', 'high': '3.1874', 'low': '3.1816', 'varBid': '-0.0043', 'pctChange': '-0.13', 'bid': '3.1806', 'ask': '3.1855', 'timestamp': '1690246687', 'create_date': '2023-07-24 21:58:07'}, 'CNY': {'code': 'CNY', 'codein': 'BRL', 'name': 'Yuan Chinês/Real Brasileiro', 'high': '0.6578', 'low': '0.6578', 'varBid': '-0.0074', 'pctChange': '-1.11', 'bid': '0.6578', 'ask': '0.6578', 'timestamp': '1690243203', 'create_date': '2023-07-24 21:00:03'}, 'ILS': {'code': 'ILS', 'codein': 'BRL', 'name': 'Novo Shekel Israelense/Real Brasileiro', 'high': '1.2905', 'low': '1.2901', 'varBid': '-0.0287', 'pctChange': '-2.18', 'bid': '1.2901', 'ask': '1.2903', 'timestamp': '1690246624', 'create_date': '2023-07-24 21:57:04'}, 'ETH': {'code': 'ETH', 'codein': 'BRL', 'name': 'Ethereum/Real Brasileiro', 'high': '9093.45', 'low': '8748.27', 'varBid': '-302.41', 'pctChange': '-3.31', 'bid': '8820', 'ask': '8846.31', 'timestamp': '1690245866', 'create_date': '2023-07-24 21:44:26'}, 'XRP': {'code': 'XRP', 'codein': 'BRL', 'name': 'XRP/Real Brasileiro', 'high': '3.57', 'low': '3.25', 'varBid': '-0.26', 'pctChange': '-7.25', 'bid': '3.31', 'ask': '3.32', 'timestamp': '1690246568', 'create_date': '2023-07-24 21:56:08'}, 'DOGE': {'code': 'DOGE', 'codein': 'BRL', 'name': 'Dogecoin/Real Brasileiro', 'high': '0.36968', 'low': '0.33747', 'varBid': '0.00934', 'pctChange': '2.72', 'bid': '0.35296', 'ask ...

# %%
import pandas as pd

tabela = pd.DataFrame.from_dict(cota_dic, orient='index')
display(tabela)
# Out:
#       code codein                                     name     high      low  \
# USD    USD    BRL          Dólar Americano/Real Brasileiro   4.7288   4.7271
# USDT   USD   BRLT  Dólar Americano/Real Brasileiro Turismo     4.76     4.76
# CAD    CAD    BRL          Dólar Canadense/Real Brasileiro   3.5916   3.5881
# GBP    GBP    BRL          Libra Esterlina/Real Brasileiro   6.0648   6.0533
# ARS    ARS    BRL           Peso Argentino/Real Brasileiro   0.0174   0.0174
# BTC    BTC    BRL                  Bitcoin/Real Brasileiro   144967   138000
# LTC    LTC    BRL                 Litecoin/Real Brasileiro   449.03   419.01
# EUR    EUR    BRL                     Euro/Real Brasileiro   5.2325   5.2292
# JPY    JPY    BRL             Iene Japonês/Real Brasileiro  0.03343  0.03339
# CHF    CHF    BRL             Franco Suíço/Real Brasileiro   5.4384   5.4337
# AUD    AUD    BRL        Dólar Australiano/Real Brasileiro   3.1874   3.1816
# CNY    CNY    BRL              Yuan Chinês/Real Brasileiro   0.6578   0.6578
# ILS    ILS    BRL   Novo Shekel Israelense/Real Brasileiro   1.2905   1.2901
# ETH    ETH    BRL                 Ethereum/Real Brasileiro  9093.45  8748.27
# XRP    XRP    BRL                      XRP/Real Brasileiro     3.57     3.25
# DOGE  DOGE    BRL                 Dogecoin/Real Brasileiro  0.36968  0.33747
#
#        varBid pctChange      bid      ask   timestamp          create_date
# USD    0.0001         0   4.7269   4.7274  1690232405  2023-07-24 18:00:05
# USDT        0         0     4.62      4.9  1690225560  2023-07-24 16:06:00
# CAD   -0.0017     -0.05   3.5867   3.5922  1690246703  2023-07-24 21:58:23
# GBP   -0.0023     -0.04   6.0533    6.068  1690246695  2023-07-24 21:58:15
# ARS         0         0   0.0174   0.0174  1690246687  2023-07-24 21:58:07
# BTC     -5872     -4.05   139041   139041  1690246548  2023-07-24 21:55:48
# LTC    -22.84     -5.09   424.23    425.5  1690246595  2023-07-24 21:56:35
# EUR    0.0005      0.01   5.2285   5.2365  1690246700  2023-07-24 21:58:20
# JPY         0         0  0.03342  0.03344  1690246690  2023-07-24 21:58:10
# CHF    0.0011      0.02   5.4342   5.4425  1690246695  2023-07-24 21:58:15
# AUD   -0.0043     -0.13   3.1806   3.1855  1690246687  2023-07-24 21:58:07
# CNY   -0.0074     -1.11   0.6578   0.6578  1690243203  2023-07-24 21:00:03
# ILS   -0.0287     -2.18   1.2901   1.2903  1690246624  2023-07-24 21:57:04
# ETH   -302.41     -3.31     8820  8846.31  1690245866  2023-07-24 21:44:26
# XRP     -0.26     -7.25     3.31     3.32  1690246568  2023-07-24 21:56:08
# DOGE  0.00934      2.72  0.35296  0.35296  1690246518  2023-07-24 21:55:18

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin? (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %%
print({f"Dolar: {cota_dic['USD']['bid']}"})
print({f"Euro: {cota_dic['EUR']['bid']}"})
print({f"Libra: {cota_dic['GBP']['bid']}"})
print({f"Bitcoin: {cota_dic['BTC']['bid']}"})
print({f"Peso: {cota_dic['ARS']['bid']}"})
# Out:
# {'Dolar: 4.7269'}
# {'Euro: 5.2285'}
# {'Libra: 6.0533'}
# {'Bitcoin: 139041'}
# {'Peso: 0.0174'}

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %%
cota2 = requests.get("https://economia.awesomeapi.com.br/json/daily/USD/30")
cota_dic2 = cota2.json()
# display(cota_dic2[0])

lista_bid = [float(item['bid']) for item in cota_dic2] 
tabela = pd.DataFrame(lista_bid)
tabela.rename(columns={0: 'Bid Dolar'}, inplace=True)  # Remova o argumento inplace=True

display(tabela)
# Out:
#     Bid Dolar
# 0      4.7269
# 1      4.7269
# 2      4.7800
# 3      4.7804
# 4      4.7970
# 5      4.7903
# 6      4.8108
# 7      4.8073
# 8      4.7889
# 9      4.7899
# 10     4.7908
# 11     4.8006
# 12     4.8187
# 13     4.8531
# 14     4.9000
# 15     4.8715
# 16     4.8723
# 17     4.9188
# 18     4.8484
# 19     4.8408
# 20     4.8102
# 21     4.7858
# 22     4.7870
# 23     4.8553
# 24     4.8506
# 25     4.8103
# 26     4.7690
# 27     4.7864
# 28     4.7844
# 29     4.7725

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan